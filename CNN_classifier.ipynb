# %% [markdown]
# # **Background information:**
#
# Welcome to the coding challenging! This will be a 3-part challenge and you will develop an image processing and computer vision techniques to analyze the health of Solar photovoltaic (PV) systems. The challenege will be judged based on these  three results.
#
# **(a)**Bench marking classification results that can be shared broadly with the community.
#
#
# **(b)**Algorithm optimization towards real-time classification that can be used by low performance edge-computing devices.
#
# ## **Bonus**
# **(c)** Incorporation of more classes and the ability to recognize anomalies that are outside of the 12 classes of InfraredSolarModules.
#
#
# We will be focusing on Solar photovoltaic (PV) datasets. Here's something we'd like you to know before you start:
#
# We would like you to pre-process, visualize, perform an exploratory data analysis. Correlation analysis and anything you can think of are welcomed.
#
#
#
#
# If you have any questions, feel free to reach out to **@Tannistha** :)

# %% [markdown]
# ## **Data downloads and requirements**:
#
# We will use datasets from:
# https://github.com/RaptorMaps/InfraredSolarModules
#
#
# You are encouraged to use Python and its libraries for this challenge. For evaluation, we recommend numpy, pandas, matplotlib and seaborn for part a and Keras or PyTorch for part b. Please submit your work as one single .ipynb (recommended) or .py file.
# Please attach your model file that has weight (pkl) and a explain how to use it with new dataset.

# %% [markdown]
# ### Link to previous work is available on
#
# *   InfraRed Thermography:
#
# https://www.mdpi.com/1424-8220/20/4/1055
#
# https://www.mdpi.com/1424-8220/20/4/1055
# *   Other relevant links
#
#
#
# http://arxiv.org/abs/1807.02894
#
# https://ai4earthscience.github.io/iclr-2020-workshop/papers/ai4earth22.pdf
#
# https://onlinelibrary.wiley.com/doi/abs/10.1002/pip.3191
#
# https://www.sciencedirect.com/science/article/abs/pii/S0038092X20308665

# %% [markdown]
# ### **Prepare Data**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as img
import numpy as np
import json
import os
import random
import tensorflow as tf

# %%
os.listdir('./')
# Out:
# ['.ipynb_checkpoints',
#  'CNN_classifier.ipynb',
#  'data.csv',
#  'Data_exploration.ipynb',
#  'holdout_set.docx',
#  'holdout_set.txt',
#  'images',
#  'labels.csv',
#  'module_metadata.json',
#  'SVC_classifier.ipynb']

# %%
with open("./module_metadata.json", 'r') as read_file:
    data = json.load(read_file)

# %%
df_files = pd.DataFrame(data)
df_files.head()
# Out:
#                            13357             13356             19719  \
# image_filepath  images/13357.jpg  images/13356.jpg  images/19719.jpg
# anomaly_class         No-Anomaly        No-Anomaly        No-Anomaly
#
#                            11542             11543             11540  \
# image_filepath  images/11542.jpg  images/11543.jpg  images/11540.jpg
# anomaly_class         No-Anomaly        No-Anomaly        No-Anomaly
#
#                            11541             11546             11547  \
# image_filepath  images/11541.jpg  images/11546.jpg  images/11547.jpg
# anomaly_class         No-Anomaly        No-Anomaly        No-Anomaly
#
#                            11544  ...             8483             8484  \
# image_filepath  images/11544.jpg  ...  images/8483.jpg  images/8484.jpg
# anomaly_class         No-Anomaly  ...       Vegetation       Vegetation
#
#                            8485             8486             8487  \
# image_filepath  images/8485.jpg  images/8486.jpg  images/8487.jpg
# anomaly_class        Vegetation       Vegetation       Vegetation
#
#                            8488             8489             7464  \
# image_filepath  images/8488.jpg  images/8489.jpg  images/7464.jpg
# anomaly_class        Vegetation       Vegetation         Cracking
#
#                            18065             13354
# image_filepath  images/18065.jpg  images/13354.jpg
# anomaly_class         No-Anomaly        No-Anomaly
#
# [2 rows x 19903 columns]

# %%
def loadFiles(data):
    new_df = []
    for file in data.iloc[0]:
        img_data = img.imread(file)
        new_df.append(img_data / 255)
    return np.array(new_df)

# %%
X = loadFiles(df_files)
X
# Out:
# array([[[0.55294118, 0.57647059, 0.61568627, ..., 0.60392157,
#          0.58039216, 0.55294118],
#         [0.55686275, 0.58431373, 0.62352941, ..., 0.59215686,
#          0.56862745, 0.54509804],
#         [0.56078431, 0.58823529, 0.63137255, ..., 0.60392157,
#          0.58431373, 0.56470588],
#         ...,
#         [0.54509804, 0.54509804, 0.57647059, ..., 0.58039216,
#          0.57254902, 0.54509804],
#         [0.50980392, 0.51372549, 0.54117647, ..., 0.53333333,
#          0.5254902 , 0.49411765],
#         [0.45490196, 0.45490196, 0.4745098 , ..., 0.45882353,
#          0.44705882, 0.41568627]],
#
#        [[0.38823529, 0.37254902, 0.35686275, ..., 0.64705882,
#          0.64705882, 0.64313725],
#         [0.40392157, 0.39607843, 0.38823529, ..., 0.62745098,
#          0.64313725, 0.65098039],
#         [0.45882353, 0.45098039, 0.45098039, ..., 0.6       ,
#          0.62352941, 0.63921569],
#         ...,
#         [0.56862745, 0.57254902, 0.58431373, ..., 0.61176471,
#          0.58823529, 0.56862745],
#         [0.56078431, 0.56470588, 0.57647059, ..., 0.60392157,
#          0.58431373, 0.56470588],
#         [0.54901961, 0.55686275, 0.57254902, ..., 0.6       ,
#          0.58039216, 0.56470588]],
#
#        [[0.96470588, 0.98823529, 0.98039216, ..., 0.86666667,
#          0.90196078, 0.91372549],
#         [0.96470588, 0.98431373, 0.97254902, ..., 0.8627451 ,
#          0.89411765, 0.90980392],
#         [0.97254902, 0.98431373, 0.97254902, ..., 0.87843137,
#          0.90980392, 0.92156863],
#         ...,
#         [0.91764706, 0.89803922, 0.89803922, ..., 0.92156863,
#          0.9254902 , 0.91372549],
#         [0.90196078, 0.87843137, 0.8745098 , ..., 0.89803922,
#          0.90588235, 0.90196078],
#         [0.90196078, 0.8745098 , 0.87058824, ..., 0.89019608,
#          0.90588235, 0.90588235]],
#
#        ...,
#
#        [[0.68235294, 0.67058824, 0.65098039, ..., 0.65490196,
#          0.63529412, 0.59607843],
#         [0.6745098 , 0.65882353, 0.63921569, ..., 0.69019608,
#          0.66666667, 0.62745098],
#         [0.69019608, 0.6745098 , 0.65490196, ..., 0.75686275,
#          0.72156863, 0.68627451],
#         ...,
#         [0.5254902 , 0.53333333, 0.56078431, ..., 0.8745098 ,
#          0.85490196, 0.78431373],
#         [0.50980392, 0.51372549, 0.53333333, ..., 0.87843137,
#          0.85882353, 0.77254902],
#         [0.48235294, 0.48627451, 0.50196078, ..., 0.8       ,
#          0.76862745, 0.67058824]],
#
#        [[0.78039216, 0.78823529, 0.79215686, ..., 0.80784314,
#          0.79607843, 0.78823529],
#         [0.80784314, 0.81568627, 0.81960784, ..., 0.82745098,
#          0.81176471, 0.8       ],
#         [0.82745098, 0.83137255, 0.83921569, ..., 0.84705882,
#          0.82352941, 0.81176471],
#         ...,
#         [0.79215686, 0.8       , 0.80784314, ..., 0.83921569,
#          0.82352941, 0.81176471],
#         [0.79215686, 0.79215686, 0.79607843, ..., 0.83137255,
#          0.81568627, 0.80392157],
#         [0.79215686, 0.78823529, 0.79215686, ..., 0.82352941,
#          0.81176471, 0.80392157]],
#
#        [[0.56470588, 0.58039216, 0.59215686, ..., 0.55686275,
#          0.54509804, 0.5372549 ],
#         [0.50980392, 0.53333333, 0.54901961, ..., 0.52941176,
#          0.52156863, 0.51372549],
#         [0.49019608, 0.5254902 , 0.54901961, ..., 0.54509804,
#          0.54509804, 0.54901961],
#         ...,
#         [0.69411765, 0.70588235, 0.71372549, ..., 0.65098039,
#          0.64313725, 0.62745098],
#         [0.70196078, 0.70980392, 0.71372549, ..., 0.65882353,
#          0.65882353, 0.65098039],
#         [0.69411765, 0.70588235, 0.70980392, ..., 0.64313725,
#          0.64705882, 0.63921569]]])

# %%
y = df_files.iloc[1]
y.to_numpy()
# Out:
# array(['No-Anomaly', 'No-Anomaly', 'No-Anomaly', ..., 'Cracking',
#        'No-Anomaly', 'No-Anomaly'], dtype=object)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
le.fit(['No-Anomaly', 'Cell', 'Cell-Multi', 'Cracking', 'Diode', 'Diode-Multi', 'Hot-Spot', 'Hot-Spot-Multi', 'Offline-Module', 'Shadowing', 'Soiling', 'Vegetation'])
labels = le.transform(y)
classes = dict(enumerate(le.classes_))
print(classes)
# Out:
# {0: 'Cell', 1: 'Cell-Multi', 2: 'Cracking', 3: 'Diode', 4: 'Diode-Multi', 5: 'Hot-Spot', 6: 'Hot-Spot-Multi', 7: 'No-Anomaly', 8: 'Offline-Module', 9: 'Shadowing', 10: 'Soiling', 11: 'Vegetation'}

# %% [markdown]
# ### **Create Model**

# %%
img_rows, img_cols = 40, 24
image_shape = (40, 24, 1)
num_classes = 12

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dropout, Flatten, Dense, Conv2D, MaxPooling2D

def classificationModel(filters_list, nodes_list, conv_filter_size, pool_filter_size, activation_list, dropout):

    model = Sequential()
    model.add(Conv2D(filters_list[0], conv_filter_size, activation=activation_list[0], padding='same', input_shape=image_shape))
    model.add(MaxPooling2D(pool_size=pool_filter_size, padding='same'))
    model.add(Conv2D(filters_list[1], conv_filter_size, activation=activation_list[0]))
    model.add(MaxPooling2D(pool_size=pool_filter_size))
  #  model.add(Conv2D(filters_list[2], conv_filter_size, activation=activation_list[0]))
  #  model.add(MaxPooling2D(pool_size=pool_filter_size))
    model.add(Flatten())
    model.add(Dense(nodes_list[0], activation=activation_list[0]))
    model.add(Dense(nodes_list[1], activation=activation_list[0]))
    model.add(Dropout(dropout))
    model.add(Dense(nodes_list[2], activation=activation_list[1]))
    
    return model

# %%
model = classificationModel([20, 32, 48], [192, 48, num_classes], (1), (2), ['relu', 'softmax'], 0.25)
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 40, 24, 20)        40
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 20, 12, 20)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 20, 12, 32)        672
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 10, 6, 32)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 1920)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 192)               368832
# _________________________________________________________________
# dense_8 (Dense)              (None, 48)                9264
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 48)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 12)                588
# =================================================================
# Total params: 379,396
# Trainable params: 379,396
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['AUC'])

# %%
batch_size = 32
epochs = 8

# %% [markdown]
# ### **Train Model**
#
# Cross-validation done using the stratified K-fold method

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold

# %%
skf = StratifiedKFold()
skf.get_n_splits(X,y)
# Out:
# 5

# %%
histories = []
predictions = []

for train_index, test_index in skf.split(X, y):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    print(X_train.shape, y_train.shape)
    histories.append(model.fit(tf.expand_dims(X_train,-1), to_categorical(le.transform(y_train)), batch_size, epochs, 
                                validation_data=(tf.expand_dims(X_test,-1), to_categorical(le.transform(y_test)))))
    predictions.append(model.predict(tf.expand_dims(X_test,-1)))
# Out:
# (15922, 40, 24) (15922,)
# Epoch 1/8
# 498/498 [==============================] - 6s 13ms/step - loss: 1.8147 - auc: 0.8153 - val_loss: 1.7360 - val_auc: 0.8354
# Epoch 2/8
# 498/498 [==============================] - 6s 12ms/step - loss: 1.7501 - auc: 0.8321 - val_loss: 1.7155 - val_auc: 0.8435
# Epoch 3/8
# 498/498 [==============================] - 6s 12ms/step - loss: 1.7131 - auc: 0.8428 - val_loss: 1.6763 - val_auc: 0.8561
# Epoch 4/8
# 498/498 [==============================] - 6s 12ms/step - loss: 1.6608 - auc: 0.8565 - val_loss: 1.6054 - val_auc: 0.8715
# Epoch 5/8
# 498/498 [==============================] - 6s 12ms/step - loss: 1.5965 - auc: 0.8689 - val_loss: 1.5134 - val_auc: 0.8856
# Epoch 6/8
# 498/498 [==============================] - 6s 12ms/step - loss: 1.5218 - auc: 0.8821 - val_loss: 1.4472 - val_auc: 0.8947
# Epoch 7/8
# 498/498 [==============================] - 6s 11ms/step - loss: 1.4610 - auc: 0.8913 - val_loss: 1.3980 - val_auc: 0.9034
# Epoch 8/8
# 498/498 [==============================] - 6s 12ms/step - loss: 1.3937 - auc: 0.9015 - val_loss: 1.3138 - val_auc: 0.9142
# (15922, 40, 24) (15922,)
# Epoch 1/8
# 498/498 [==============================] - 6s 11ms/step - loss: 1.3544 - auc: 0.9071 - val_loss: 1.3071 - val_auc: 0.9164
# Epoch 2/8
# 498/498 [==============================] - 6s 12ms/step - loss: 1.3104 - auc: 0.9129 - val_loss: 1.2578 - val_auc: 0.9199
# Epoch 3/8
# 498/498 [==============================] - 6s 12ms/step - loss: 1.2780 - auc: 0.9173 - val_loss: 1.2326 - val_auc: 0.9225
# Epoch 4/8
# 498/498 [==============================] - 6s 12ms/step - loss: 1.2565 - auc: 0.9194 - val_loss: 1.2433 - val_auc: 0.9224
# Epoch 5/8
# 498/498 [==============================] - 6s 12ms/step - loss: 1.2318 - auc: 0.9229 - val_loss: 1.1996 - val_auc: 0.9270
# Epoch 6/8
# 498/498 [==============================] - 6s 12ms/step - loss: 1.2161 - auc: 0.9247 - val_loss: 1.2277 - val_auc: 0.9259
# Epoch 7/8
# 498/498 [==============================] - 6s 12ms/step - loss: 1.1978 - auc: 0.9273 - val_loss: 1.2050 - val_auc: 0.9274
# Epoch 8/8
# 498/498 [==============================] - 6s 12ms/step - loss: 1.1824 - auc: 0.9290 - val_loss: 1.1723 - val_auc: 0.9299
# (15922, 40, 24) (15922,)
# Epoch 1/8
# 498/498 [==============================] - 6s 12ms/step - loss: 1.1883 - auc: 0.9286 - val_loss: 1.1122 - val_auc: 0.9386
# Epoch 2/8
# 498/498 [==============================] - 6s 12ms/step - loss: 1.1782 - auc: 0.9299 - val_loss: 1.1069 - val_auc: 0.9392
# Epoch 3/8
# 498/498 [==============================] - 6s 12ms/step - loss: 1.1533 - auc: 0.9326 - val_loss: 1.1013 - val_auc: 0.9392
# Epoch 4/8
# 498/498 [==============================] - 6s 13ms/step - loss: 1.1471 - auc: 0.9332 - val_loss: 1.1500 - val_auc: 0.9361
# Epoch 5/8
# 498/498 [==============================] - 6s 12ms/step - loss: 1.1378 - auc: 0.9345 - val_loss: 1.1016 - val_auc: 0.9390
# Epoch 6/8
# 498/498 [==============================] - 6s 12ms/step - loss: 1.1300 - auc: 0.9353 - val_loss: 1.0831 - val_auc: 0.9405
# Epoch 7/8
# 498/498 [==============================] - 6s 12ms/step - loss: 1.1214 - auc: 0.9363 - val_loss: 1.1165 - val_auc: 0.9372
# Epoch 8/8
# 498/498 [==============================] - 6s 12ms/step - loss: 1.0989 - auc: 0.9390 - val_loss: 1.0896 - val_auc: 0.9405
# (15923, 40, 24) (15923,)
# Epoch 1/8
# 498/498 [==============================] - 6s 12ms/step - loss: 1.1027 - auc: 0.9383 - val_loss: 1.0324 - val_auc: 0.9460
# Epoch 2/8
# 498/498 [==============================] - 6s 13ms/step - loss: 1.0937 - auc: 0.9393 - val_loss: 1.0973 - val_auc: 0.9384
# Epoch 3/8
# 498/498 [==============================] - 6s 13ms/step - loss: 1.0780 - auc: 0.9411 - val_loss: 1.0304 - val_auc: 0.9460
# Epoch 4/8
# 498/498 [==============================] - 6s 13ms/step - loss: 1.0713 - auc: 0.9417 - val_loss: 1.0259 - val_auc: 0.9475
# Epoch 5/8
# 498/498 [==============================] - 7s 13ms/step - loss: 1.0629 - auc: 0.9428 - val_loss: 1.0335 - val_auc: 0.9460
# Epoch 6/8
# 498/498 [==============================] - 7s 14ms/step - loss: 1.0595 - auc: 0.9432 - val_loss: 1.0568 - val_auc: 0.9449
# Epoch 7/8
# 498/498 [==============================] - 7s 14ms/step - loss: 1.0505 - auc: 0.9442 - val_loss: 1.0291 - val_auc: 0.9465
# Epoch 8/8
# 498/498 [==============================] - 7s 14ms/step - loss: 1.0416 - auc: 0.9451 - val_loss: 1.0211 - val_auc: 0.9470
# (15923, 40, 24) (15923,)
# Epoch 1/8
# 498/498 [==============================] - 7s 14ms/step - loss: 1.0533 - auc: 0.9441 - val_loss: 0.9801 - val_auc: 0.9516
# Epoch 2/8
# 498/498 [==============================] - 7s 14ms/step - loss: 1.0435 - auc: 0.9451 - val_loss: 0.9765 - val_auc: 0.9518
# Epoch 3/8
# 498/498 [==============================] - 7s 13ms/step - loss: 1.0429 - auc: 0.9448 - val_loss: 0.9594 - val_auc: 0.9547
# Epoch 4/8
# 498/498 [==============================] - 7s 13ms/step - loss: 1.0284 - auc: 0.9462 - val_loss: 0.9417 - val_auc: 0.9561
# Epoch 5/8
# 498/498 [==============================] - 7s 14ms/step - loss: 1.0147 - auc: 0.9479 - val_loss: 0.9433 - val_auc: 0.9549
# Epoch 6/8
# 498/498 [==============================] - 7s 14ms/step - loss: 1.0120 - auc: 0.9484 - val_loss: 0.9672 - val_auc: 0.9528
# Epoch 7/8
# 498/498 [==============================] - 7s 15ms/step - loss: 1.0028 - auc: 0.9497 - val_loss: 0.9663 - val_auc: 0.9552
# Epoch 8/8
# 498/498 [==============================] - 7s 14ms/step - loss: 1.0027 - auc: 0.9493 - val_loss: 0.9550 - val_auc: 0.9539

# %% [markdown]
# ### **Evaluate Results**

# %%
def plotmetric(history, metric):
    plt.title("Model "+metric.title())
    plt.plot(history.history[metric])
    plt.plot(history.history['val_'+metric])
    plt.xlabel('epoch')
    plt.ylabel('metric')
    #plt.ylim([0,1])
    plt.show()

# %%
for history in histories:
    plotmetric(history, 'auc')

# %%
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.metrics import classification_report,multilabel_confusion_matrix

# %%
def plot_roc_curve(y_true, y_pred, n):
    fpr, tpr, thresholds = roc_curve(y_true, y_pred)
    plt.plot(fpr, tpr, color='orange', label='ROC')
    plt.plot([0, 1], [0, 1], color='darkblue', linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(classes.get(n))
    plt.legend()
    plt.show()

# %%
pred_proba = model.predict(tf.expand_dims(x_test,-1))
for n in classes.keys():
    plot_roc_curve(to_categorical(le.transform(y_test))[:,n], pred_proba[:,n], n)

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
y_pred = (pred_proba > 0.5)
print(classification_report(to_categorical(le.transform(y_test)),y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.63      0.27      0.37       591
#            1       0.75      0.02      0.04       407
#            2       0.76      0.45      0.57       304
#            3       0.93      0.71      0.80       441
#            4       0.91      0.19      0.32        52
#            5       0.00      0.00      0.00        78
#            6       0.58      0.12      0.20        59
#            7       0.78      0.95      0.86      2934
#            8       0.83      0.02      0.04       221
#            9       0.87      0.17      0.29       317
#           10       1.00      0.01      0.03        69
#           11       0.68      0.36      0.47       498
#
#    micro avg       0.78      0.61      0.69      5971
#    macro avg       0.73      0.27      0.33      5971
# weighted avg       0.76      0.61      0.61      5971
#  samples avg       0.61      0.61      0.61      5971
# C:\Users\David\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\David\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
multilabel_confusion_matrix(to_categorical(le.transform(y_test)),y_pred)
# Out:
# array([[[5287,   93],
#         [ 434,  157]],
#
#        [[5561,    3],
#         [ 398,    9]],
#
#        [[5624,   43],
#         [ 167,  137]],
#
#        [[5507,   23],
#         [ 130,  311]],
#
#        [[5918,    1],
#         [  42,   10]],
#
#        [[5893,    0],
#         [  78,    0]],
#
#        [[5907,    5],
#         [  52,    7]],
#
#        [[2268,  769],
#         [ 146, 2788]],
#
#        [[5749,    1],
#         [ 216,    5]],
#
#        [[5646,    8],
#         [ 262,   55]],
#
#        [[5902,    0],
#         [  68,    1]],
#
#        [[5388,   85],
#         [ 319,  179]]], dtype=int64)

# %%
score = roc_auc_score(to_categorical(le.transform(y_test)), pred_proba, multi_class='ovo')
print(score)
# Out:
# 0.9138623211381732

# %%
def predict_image_by_indx(i):
    holdout_image = X[i]
    prob = model.predict(holdout_image.reshape(1, 40, 24, 1))
    plt.imshow(holdout_image)
    pred = prob > 0.5
    print(pred[0])
    n = le.classes_[pred[0]]
    print(n)
    plt.title("Predicted: " + n[0] + "\nActual: "+y[i])

# %%
predict_image_by_indx(8483)
# Out:
# [False False False  True False False False False False False False False]
# ['Diode']
